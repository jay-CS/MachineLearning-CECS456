# %%
if __name__ == '__main__':
    ## test question (a)
    play_with_data()

#In the show features method we were given the task of taking a numpy array of size 16 by 16 , and using the data 
# to plot points. Taking every point, we can output them one by one using a plot as seen in images (a) and (b). 
# On the other hand, the values can be directly applied to an image using the imshow() function as seen in images b 
# and c. The result from plotting the data is the we receive images that represent both “1” and “5”
# Out:
# play with data done!

# %%
if __name__ == '__main__':
    ## test question (b)
    play_with_features() 

# -In this function we are using a numpy array of shape (1561,2) and (1561,1), which indicate the symmetry and 
# intensitycorresponding to the number they are (1 or 5). The points are inputted and marked on the scatter plot.
# Moreover, whenwe plot the data points, we find that number 5 has Intensity that ranges from 0.0 to - .8 and 
# symmetry from -1.0 to -.3, giving it a spread out blue cluster in the middle of the scatter plot. On the other 
# hand, the number one is shown to have intensity ranging from -.5 to -1.0 and symmetry from -.3 to 0 giving it 
# a Red cluster on the right bottom corner.
# Out:
# play with features done!

# %%
if __name__ == '__main__':
    #test question (c)
    test_accuracy()
    
#In the Perceptron function we are starting with arbitrary weights, and from there we are iterating through the list
# updating the weights if the sign of the dot product between the X row and W column vector do not much. As the weights 
# are updated initially, a lot of the misclassified errors contained in the data become fixed by the weights, which 
# means the data will be enumerated through a couple of times to find enough errors when we get to like 200 iterations. 
# Final result yields different weight values, however, the accuracy even with different weight values still converges 
# towards 98.1% accuracy in the training set and 96.1% accuracy in the testing set.
# Out:
# Case 1 train accuracy:0.973735  test accuracy: 0.948113
# Case 2 train accuracy:0.973735  test accuracy: 0.948113
# Case 3 train accuracy:0.973735  test accuracy: 0.948113
# Case 4 train accuracy:0.979500  test accuracy: 0.959906
# Case 5 train accuracy:0.979500  test accuracy: 0.959906
# Case 6 train accuracy:0.979500  test accuracy: 0.959906
# Case 7 train accuracy:0.979500  test accuracy: 0.959906
# Case 8 train accuracy:0.979500  test accuracy: 0.959906
# Case 9 train accuracy:0.979500  test accuracy: 0.959906
# Case 10 train accuracy:0.979500  test accuracy: 0.959906
# accuracy test done!

# %%
if __name__ == '__main__':
    # test question (d)
    play_with_result()
    
# In this function we are doing the same thing as play_with_features() method, except we will be plotting points from 
# the test data set with the symmetry, intensity, and label given. In addition, using the weights we obtained from the 
# perceptron method, we will plot the slope of y = ax + b where ‘a’ is -w[0][1]/w[0][2]  and ‘b’ is  -w[0][0]/w[0][2] 
# which will turn into 0 since the bias is 0. The final result is a scatter plot similar to play_with_features() with 
# the line y = a*x + b separating most of the 5’s of 1’s distinctly except for very few misclassified points since the 
# data is Not linearly separable.
# Out:
# play with result done!
